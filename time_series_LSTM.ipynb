# %%
pip install wget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Time Series Prediction with LSTM Using PyTorch

# %%
# !python -m wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly_champagne_sales.csv
# Out:
# Saved under monthly_champagne_sales.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Data Plot

# %%
training_set_champagne = pd.read_csv('data/monthly_champagne_sales.csv')
training_set_airline = pd.read_csv('data/airline-passengers.csv')
training_set_shampoo = pd.read_csv('data/shampoo.csv')

training_set_champagne = training_set_champagne.iloc[:,1:2].values
training_set_airline = training_set_airline.iloc[:,1:2].values
training_set_shampoo = training_set_shampoo.iloc[:,1:2].values

# %%
#monthly_champagne_sales
plt.plot(training_set_champagne, label = 'Monthly Champagne Sales Data')
plt.show()

# %%
#airline-passengers
plt.plot(training_set_airline, label = 'airline Passengers Data')
plt.show()

# %%
#Shampoo Sales Data
plt.plot(training_set_shampoo, label = 'Shampoo Sales Data')
plt.show()

# %% [markdown]
# Dataloading

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
#Airline
#training_data = sc.fit_transform(training_set_airline)

#Shampoo
#training_data = sc.fit_transform(training_set_shampoo)

#Champagne
training_data = sc.fit_transform(training_set_champagne)


seq_length = 4
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.67)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %% [markdown]
# Model

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %% [markdown]
# Training

# %%
num_epochs = 2000
learning_rate = 0.01

input_size = 1
hidden_size = 2
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()
    if epoch % 100 == 0:
      print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# Epoch: 0, loss: 0.08232
# Epoch: 100, loss: 0.01541
# Epoch: 200, loss: 0.01327
# Epoch: 300, loss: 0.01103
# Epoch: 400, loss: 0.01012
# Epoch: 500, loss: 0.00965
# Epoch: 600, loss: 0.00901
# Epoch: 700, loss: 0.00799
# Epoch: 800, loss: 0.00680
# Epoch: 900, loss: 0.00625
# Epoch: 1000, loss: 0.00597
# Epoch: 1100, loss: 0.00568
# Epoch: 1200, loss: 0.00541
# Epoch: 1300, loss: 0.00509
# Epoch: 1400, loss: 0.00488
# Epoch: 1500, loss: 0.00463
# Epoch: 1600, loss: 0.00444
# Epoch: 1700, loss: 0.00430
# Epoch: 1800, loss: 0.00420
# Epoch: 1900, loss: 0.00401

# %% [markdown]
# Testing for Shampoo Sales Dataset

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()

# %% [markdown]
# Testing for Airplane Passengers Dataset

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()

# %% [markdown]
# Testing for Monthly Champagne Dataset

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()
